# %%
# %matplotlib inline
import pandas as pd

# %%
cols = [
    "fritz",
    "klaus",
    "draw",
#     "invalid_moves_klaus",
#     "invalid_moves_fritz",
]
data = pd.read_csv("results.csv").fillna(0)
data[cols].plot(figsize=(15,5))
data.iloc[-1]
# Out:
# Unnamed: 0             179.0
# draw                     0.0
# fritz                   56.0
# invalid_moves_fritz      2.0
# invalid_moves_klaus      0.0
# klaus                   44.0
# Name: 179, dtype: float64
